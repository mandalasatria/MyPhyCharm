# %%
import matplotlib.pyplot as plt

# Data dari hasil training
epochs = list(range(1, 21))
train_loss = [0.2713, 0.1105, 0.0820, 0.0665, 0.0616, 0.0517, 0.0438, 0.0396, 0.0374, 0.0347,
              0.0329, 0.0335, 0.0279, 0.0282, 0.0292, 0.0267, 0.0249, 0.0233, 0.0274, 0.0236]
val_loss = [0.1634, 0.0893, 0.1096, 0.0716, 0.0848, 0.0752, 0.0638, 0.1112, 0.1013, 0.0843,
            0.0944, 0.0824, 0.0979, 0.0833, 0.0663, 0.0706, 0.0841, 0.0780, 0.0952, 0.1121]
train_accuracy = [0.9080, 0.9639, 0.9753, 0.9801, 0.9807, 0.9842, 0.9866, 0.9890, 0.9895, 0.9904,
                  0.9911, 0.9911, 0.9933, 0.9932, 0.9930, 0.9943, 0.9937, 0.9949, 0.9938, 0.9953]
val_accuracy = [0.9551, 0.9761, 0.9687, 0.9807, 0.9769, 0.9810, 0.9844, 0.9703, 0.9727, 0.9774,
                0.9759, 0.9812, 0.9786, 0.9825, 0.9852, 0.9831, 0.9825, 0.9850, 0.9840, 0.9768]

# Membuat grafik loss
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss per Epoch')
plt.legend()
plt.show()

# Membuat grafik akurasi
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_accuracy, label='Train Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy per Epoch')
plt.legend()
plt.show()
